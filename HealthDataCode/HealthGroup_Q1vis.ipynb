# %%
import pandas as pd

life_exp_male = pd.read_csv('Life_Expectancy_Male.csv',skiprows=4)
life_exp_female = pd.read_csv('Life_Expectancy_Female.csv',skiprows=4)

dropcols = ['Indicator Name','Indicator Code','Unnamed: 65','2020']
life_exp_male.drop(dropcols,inplace=True,axis=1)
life_exp_male.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 62 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  266 non-null    object
#  1   Country Code  266 non-null    object
#  2   1960          237 non-null    float64
#  3   1961          238 non-null    float64
#  4   1962          238 non-null    float64
#  5   1963          237 non-null    float64
#  6   1964          237 non-null    float64
#  7   1965          238 non-null    float64
#  8   1966          238 non-null    float64
#  9   1967          238 non-null    float64
#  10  1968          238 non-null    float64
#  11  1969          238 non-null    float64
#  12  1970          239 non-null    float64
#  13  1971          238 non-null    float64
#  14  1972          238 non-null    float64
#  15  1973          239 non-null    float64
#  16  1974          238 non-null    float64
# ...

# %%
# drop columns for female
life_exp_female.drop(dropcols,inplace=True,axis=1)

# %%
life_exp_female.info()
life_exp_female.dropna(axis=0,inplace=True)
life_exp_male.dropna(axis=0,inplace=True)
life_exp_female.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 62 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  266 non-null    object
#  1   Country Code  266 non-null    object
#  2   1960          237 non-null    float64
#  3   1961          238 non-null    float64
#  4   1962          238 non-null    float64
#  5   1963          237 non-null    float64
#  6   1964          237 non-null    float64
#  7   1965          238 non-null    float64
#  8   1966          238 non-null    float64
#  9   1967          238 non-null    float64
#  10  1968          238 non-null    float64
#  11  1969          238 non-null    float64
#  12  1970          239 non-null    float64
#  13  1971          238 non-null    float64
#  14  1972          238 non-null    float64
#  15  1973          239 non-null    float64
#  16  1974          238 non-null    float64
# ...

# %%
# east asia pacific
EastAsiaPacific_male = life_exp_male[life_exp_male['Country Code'] == 'EAS']
EastAsiaPacific_female = life_exp_female[life_exp_female['Country Code'] == 'EAS']

# north america
NorthAmerica_male = life_exp_male[life_exp_male['Country Code'] == 'NAC']
NorthAmerica_female = life_exp_female[life_exp_female['Country Code'] == 'NAC']

EastAsiaPacific_male.shape
life_exp_male.shape
# Out:
# (237, 62)

# %%
# import matplotlib and datetime
import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline

# extract proper values for plotting
fig = plt.figure(figsize=(10,10))

EastAsiaPacific_femaleYEARS = list(EastAsiaPacific_female.iloc[:])[2:]
EastAsiaPacific_femaleVALUES = list(EastAsiaPacific_female.iloc[0][2:])
ax1 = plt.plot(EastAsiaPacific_femaleYEARS,EastAsiaPacific_femaleVALUES)

EastAsiaPacific_maleYEARS = list(EastAsiaPacific_male.iloc[:])[2:]
EastAsiaPacific_maleVALUES = list(EastAsiaPacific_male.iloc[0][2:])
ax2 = plt.plot(EastAsiaPacific_maleYEARS,EastAsiaPacific_maleVALUES)

NorthAmerica_femaleYEARS = list(NorthAmerica_female.iloc[:])[2:]
NorthAmerica_femaleVALUES = list(NorthAmerica_female.iloc[0][2:])
ax3 = plt.plot(NorthAmerica_femaleYEARS,NorthAmerica_femaleVALUES)

NorthAmerica_maleYEARS = list(NorthAmerica_male.iloc[:])[2:]
NorthAmerica_maleVALUES = list(NorthAmerica_male.iloc[0][2:])
ax4 = plt.plot(NorthAmerica_maleYEARS,NorthAmerica_maleVALUES)

years = EastAsiaPacific_femaleYEARS
values = [EastAsiaPacific_femaleVALUES,EastAsiaPacific_maleVALUES,NorthAmerica_femaleVALUES,NorthAmerica_maleVALUES]

labels = ['East Asia Female','East Asia Male','North America Female','North America Male']
plt.title('East Asian and North American Male and Female Birth Rates')
fig.legend(h)
plt.xlabel('Year')
plt.ylabel('Birth Rate')
plt.show()
# Out:
# C:\Users\cbevr\AppData\Local\Programs\Python\Python37-32\lib\site-packages\ipykernel_launcher.py:28: UserWarning: Legend does not support ['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019'] instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
